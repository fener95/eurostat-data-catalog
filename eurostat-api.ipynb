# %% [markdown]
# #Setup

# %%
# !pip install eurostat
# Out:
# Requirement already satisfied: eurostat in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from eurostat) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from eurostat) (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->eurostat) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->eurostat) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->eurostat) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->eurostat) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->eurostat) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->eurostat) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->eurostat) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->eurostat) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->eurostat) (1.16.0)

# %%
import requests
import pandas as pd
import eurostat
import json
import os

# %%
#Trick to get TOC (json or excel as well
toc_df = eurostat.get_toc_df(agency='all', dataset='all', lang='en')
toc_df.to_json('eurostat_catalog.json', orient='records', indent=4)

# %% [markdown]
# # LOOKUP by data names from the uploaed eurostat_catalog.json

# %%
# Load the catalog JSON file
with open('eurostat_catalog.json', 'r') as f:
    catalog = json.load(f)

# %%
# Search for a dataset (example: "farm")
search_term = "farm"
search_results = [item for item in catalog if search_term.lower() in item['title'].lower()]

# %%
# Display the first few results
print(json.dumps(search_results[:150], indent=4, ensure_ascii=False))
# copy the needed "code" and use it further in the fetch data module
# Out:
# [
#     {
#         "title": "Annual production and utilisation of milk on the farm",
#         "code": "MED_AG32",
#         "type": "dataset",
#         "last update of data": "2016-08-29T23:00:00+0200",
#         "last table structure change": "2024-01-10T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2015"
#     },
#     {
#         "title": "Poultry farming",
#         "code": "MED_AG34",
#         "type": "dataset",
#         "last update of data": "2020-05-28T23:00:00+0200",
#         "last table structure change": "2024-01-10T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2018"
#     },
#     {
#         "title": "Production of cow's milk on farms by NUTS 2 region",
#         "code": "TGS00046",
#         "type": "dataset",
#         "last update of data": "2024-10-07T23:00:00+0200",
#         "last table structure change": "2024-10-07T23:00:00+0200",
#         "data start": "2012",
#         "data end": "2023"
#     },
#     {
#         "title": "Farm labour force",
#         "code": "TAG00020",
#         "type": "dataset",
#         "last update of data": "2023-12-22T11:00:00+0100",
#         "last table structure change": "2023-12-22T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Production of milk on farms",
#         "code": "TAG00041",
#         "type": "dataset",
#         "last update of data": "2024-10-17T23:00:00+0200",
#         "last table structure change": "2024-10-17T23:00:00+0200",
#         "data start": "2012",
#         "data end": "2023"
#     },
#     {
#         "title": "Agricultural holdings by economic size of the farm (Standard Output in Euro)",
#         "code": "TAG00123",
#         "type": "dataset",
#         "last update of data": "2023-12-22T11:00:00+0100",
#         "last table structure change": "2023-12-22T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Arable crops: number of farms and areas of different arable crops by agricultural size of farm (UAA) and size of arable area",
#         "code": "EF_ALARABLEAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Arable crops: number of farms and areas of different arable crops by economic size of farm (SO in Euro) and size of arable area",
#         "code": "EF_ALARABLEECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Barley: number of farms and areas by agricultural size of farm (UAA) and size of barley area",
#         "code": "EF_ALBARLEY",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Cereals: number of farms and areas by agricultural size of farm (UAA) and size of cereal area",
#         "code": "EF_ALCEREAL",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Flowers and ornamental plants: number of farms and areas by agricultural size of farm (UAA)",
#         "code": "EF_ALFLOWER",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Industrial crops: number of farms and areas by agricultural size of farm (UAA) and size of industrial crop area",
#         "code": "EF_ALINDCROP",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Grain maize: number of farms and areas by agricultural size of farm (UAA) and size of grain maize area",
#         "code": "EF_ALMAIZE",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Potatoes: number of farms and area by agricultural size of farm (UAA) and size of potato area",
#         "code": "EF_ALPOTATO",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Sugar beet: number of farms and areas by agricultural size of farm (UAA) and size of sugar beet area",
#         "code": "EF_ALSBEET",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Vegetables, melons, strawberries: number of farms and areas by agricultural size of farm (UAA) and size of vegetable, melon and strawberry outdoor area",
#         "code": "EF_ALVEGE",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Common wheat: number of farms and areas by agricultural size of farm (UAA) and size of common wheat area",
#         "code": "EF_ALWHEAT",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key farm variables: area, livestock (LSU), labour force and standard output (SO) by agricultural size of farm (UAA), legal status of holding and NUTS 2 region",
#         "code": "EF_KVAAREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key farm variables: area, livestock (LSU), labour force and standard output (SO) by agricultural size of farm (UAA) and age of manager",
#         "code": "EF_KVAGE",
#         "type": "dataset",
#         "last update of data": "2017-01-18T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key variables: area, livestock (LSU), labour force and standard output (SO) by economic size of farm (SO in Euro), legal status of holding and NUTS 2 region",
#         "code": "EF_KVECSLEG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key variables: area, livestock (LSU), labour force and standard output (SO) by type of farming (2-digit) and agricultural size of farm (UAA)",
#         "code": "EF_KVFTAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key variables: area, livestock (LSU), labour force and standard output (SO) by type of farming (2-digit) and economic size of farm (SO in Euro)",
#         "code": "EF_KVFTECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key variables: area, livestock (LSU), labour force and standard output (SO) by type of farming (2-digit) and NUTS 2 region",
#         "code": "EF_KVFTREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Labour force categories: number of persons and farm work (AWU) by sex of worker, legal satus of holding and agricultural size of farm (UAA)",
#         "code": "EF_LFLEGAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Labour force categories: number of persons and farm work (AWU) by legal status of holding and economic size of farm (SO in Euro)",
#         "code": "EF_LFLEGECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Labour force categories: number of persons and farm work (AWU) in the holding by working time (% AWU) and agricultural size of farm (UAA)",
#         "code": "EF_LFWTIME",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Share of family farms by NUTS 2 region",
#         "code": "EF_LF_FAM_SH",
#         "type": "dataset",
#         "last update of data": "2024-05-28T23:00:00+0200",
#         "last table structure change": "2024-05-28T23:00:00+0200",
#         "data start": "2020",
#         "data end": "2020"
#     },
#     {
#         "title": "Main agricultural labour force by age and sex of the farm manager, farm type of the agricultural holding and NUTS 2 region",
#         "code": "EF_LF_MAIN",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Agricultural labour force by size of the farm and NUTS 2 region",
#         "code": "EF_LF_SIZE",
#         "type": "dataset",
#         "last update of data": "2024-05-27T23:00:00+0200",
#         "last table structure change": "2024-05-27T23:00:00+0200",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Main permanent crops farm",
#         "code": "EF_LPC_MAIN",
#         "type": "dataset",
#         "last update of data": "2020-12-16T11:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2013",
#         "data end": "2016"
#     },
#     {
#         "title": "Poultry: number of farms and heads by agricultural size of farm (UAA) and size of broiler flock",
#         "code": "EF_LSBROIAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Poultry: number of farms and heads by economic size of farm (SO in Euro) and size of broiler flock",
#         "code": "EF_LSBROIECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Cattle: number of farms and heads and fodder crops by agricultural size of farm (UAA) and size of cattle herd",
#         "code": "EF_LSCATL",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Cattle: number of farms and heads and fodder crops by agricultural size of farm (UAA) and livestock units (LSU) of farm",
#         "code": "EF_LSCATLAALSU",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Dairy cows: number of farms and heads and fodder crops by agricultural size of farm (UAA) and size of dairy herd",
#         "code": "EF_LSCOW",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Fodder crops: number of farms and areas by agricultural size of farm (UAA) and size of fodder crops area",
#         "code": "EF_LSFODDERAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Goats: number of farms and heads and fodder crops by agricultural size of farm (UAA) and size of goat herd",
#         "code": "EF_LSGOAT",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Organic animal farming by utilised agricultural area, livestock unit, economic size of the farm and NUTS 2 region",
#         "code": "EF_LSK_ORG",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-03-26T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Laying hens: number of farms and heads of poultry by agricultural size of farm (UAA) and size of laying hen flock",
#         "code": "EF_LSLAYHENAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Laying hens: number of farms and heads by economic size of farm (SO in Euro) and size of laying hen flock",
#         "code": "EF_LSLAYHENECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Other cows: number of farms and heads and fodder crops by agricultural size of farm (UAA) and size of other cow herd",
#         "code": "EF_LSOTHERCOW",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Pigs: number of farms and heads by agricultural size of farm (UAA) and size of pig herd",
#         "code": "EF_LSPIGAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Pigs: number of farms and heads by economic size of farm (SO in Euro) and size of pig herd",
#         "code": "EF_LSPIGECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Area under organic farming",
#         "code": "SDG_02_40",
#         "type": "dataset",
#         "last update of data": "2024-10-03T23:00:00+0200",
#         "last table structure change": "2024-10-03T23:00:00+0200",
#         "data start": "2000",
#         "data end": "2022"
#     },
#     {
#         "title": "Sheep: number of farms and heads and fodder crops by agricultural size of farm (UAA) and size of sheep flock",
#         "code": "EF_LSSHEEP",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Pigs-sows: number of farms and heads by agricultural size of farm (UAA) and size of breeding sow herd",
#         "code": "EF_LSSOWSAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Pigs-sows: number of farms and heads by economic size of farm (SO in Euro) and size of breeding sow herd",
#         "code": "EF_LSSOWSECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Poultry: number of farms and heads by size of farm (UAA) and size of broiler flock",
#         "code": "EF_LS_GVBROILER",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Poultry: number of farms and heads by size of farm (UAA) and size of laying hen flock",
#         "code": "EF_LS_GVLAYHEN",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Pigs: number of farms and heads by size of farm (UAA) and size of other pig herd",
#         "code": "EF_LS_GVOPIG",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Pigs: number of farms and heads by size of farm (UAA) and size of breeding sow herd",
#         "code": "EF_LS_GVSOWS",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Cattle: number of farms and heads by size of farm (UAA) and size of cattle herd",
#         "code": "EF_LS_GZCATL",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Cattle: number of farms and heads by size of farm (UAA) and livestock units (LSU) of farm",
#         "code": "EF_LS_GZCATLLSU",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Dairy cows: number of farms and heads by size of farm (UAA) and size of dairy herd",
#         "code": "EF_LS_GZDCOW",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Fodder crops: number of farms and areas by size of farm (UAA) and size of fodder crops area",
#         "code": "EF_LS_GZFORAGE",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Goats: number of farms and heads by size of farm (UAA) and size of goat herd",
#         "code": "EF_LS_GZGOAT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Other cows: number of farms and heads by size of farm (UAA) and size of other cow herd",
#         "code": "EF_LS_GZOCOW",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Sheep: number of farms and heads by size of farm (UAA) and size of sheep flock",
#         "code": "EF_LS_GZSHEEP",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Livestock: number of farms and heads by size of farm (UAA) and NUTS 2 region",
#         "code": "EF_LS_OVAAREG",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Livestock: number of farms and heads by economic size of farm (ESU) and NUTS 2 region",
#         "code": "EF_LS_OVESU",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Livestock: number of farms and heads by livestock units (LSU) of farm and NUTS 2 region",
#         "code": "EF_LS_OVLSUREG",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Farms and hectares by type of crops, utilised agricultural area, economic size and NUTS 2 region",
#         "code": "EF_LUS_ALLCROPS",
#         "type": "dataset",
#         "last update of data": "2024-02-27T23:00:00+0100",
#         "last table structure change": "2024-02-27T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2020"
#     },
#     {
#         "title": "Main farm land use by NUTS 2 region",
#         "code": "EF_LUS_MAIN",
#         "type": "dataset",
#         "last update of data": "2023-01-10T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2020"
#     },
#     {
#         "title": "Organic crops by utilised agricultural area, economic size of the farm and NUTS 2 region",
#         "code": "EF_LUS_ORG",
#         "type": "dataset",
#         "last update of data": "2024-05-07T11:00:00+0200",
#         "last table structure change": "2024-03-26T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Special areas and other farmland by NUTS 2 region",
#         "code": "EF_LUS_SPAREA",
#         "type": "dataset",
#         "last update of data": "2020-02-21T11:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2013",
#         "data end": "2016"
#     },
#     {
#         "title": "Arable crops: number of farms and areas by size of farm (UAA) and size of arable area",
#         "code": "EF_LU_ALARABLE",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Barley: number of farms and area by size of farm (UAA) and size of barley area",
#         "code": "EF_LU_ALBARLEY",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Cereals: number of farms, areas and combine harvestors by size of farm (UAA) and size of cereal area",
#         "code": "EF_LU_ALCEREAL",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Flowers and ornamental plants: number of farms and areas by size of farm (UAA) and size of flower and ornamental plant area",
#         "code": "EF_LU_ALFLOWER",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Industrial plants: number of farms and areas by size of farm (UAA) and size of industrial plant area",
#         "code": "EF_LU_ALIPLANT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Grain maize: number of farms and area by size of farm (UAA) and size of grain maize area",
#         "code": "EF_LU_ALMAIZE",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Potatoes: number of farms and area by size of farm (UAA) and size of potato area",
#         "code": "EF_LU_ALPOTAT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Sugar beet: number of farms and area by size of farm (UAA) and size of sugar beet area",
#         "code": "EF_LU_ALSBEET",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Vegetables, melons, strawberries and greenhouses: number of farms and areas by size of farm (UAA) and size of vegetable, melon and strawberry area under glass",
#         "code": "EF_LU_ALVEGGLAS",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Vegetables, melons, strawberries and greenhouses: number of farms and areas by size of farm (UAA) and size of vegetable, melon and strawberry outdoor area",
#         "code": "EF_LU_ALVEGOUT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Common wheat: number of farms and area by size of farm (UAA) and size of common wheat area",
#         "code": "EF_LU_ALWHEAT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Crops under glass: number of farms and areas by size of farm (UAA) and size of crops under glass area",
#         "code": "EF_LU_OFGLASS",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Permanent grassland: number of farms and areas by size of farm (UAA) and size of permanent grassland area",
#         "code": "EF_LU_OFGRASS",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Irrigation: number of farms, areas and equipment by size of farm (UAA) and NUTS 2 region",
#         "code": "EF_LU_OFIRRIG",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Fallow land and set-aside land: number of farms and areas by size of farm (UAA) and size of arable area",
#         "code": "EF_LU_OFSETASID",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Other land: number of farms and areas by size of farm (UAA) and size of wooded area",
#         "code": "EF_LU_OFWOOD",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Farmland: number of farms and areas by size of farm (UAA) and NUTS 2 region",
#         "code": "EF_LU_OVCROPAA",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Farmland: number of farms and areas by economic size of farm (ESU) and NUTS 2 region",
#         "code": "EF_LU_OVCROPESU",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Fruit and berry plantations: number of farms and areas by size of farm (UAA) and size of fruit and berry plantation area",
#         "code": "EF_LU_PCFRUIT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Permanent crops: number of farms and areas by size of farm (UAA) and size of permanent crop area",
#         "code": "EF_LU_PCGEO",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Olive plantations: number of farms and areas by size of farm (UAA) and size of olive plantation area",
#         "code": "EF_LU_PCOLIVE",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Permanent crops: number of farms and areas by size of farm (UAA), size of permanent crop area and NUTS 2 region",
#         "code": "EF_LU_PCREG",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Vineyards: number of farms and areas by size of farm (UAA) and size of vineyard area",
#         "code": "EF_LU_PCVINE",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Farm equipment: agricultural area and number of farms with different type of equipment by agricultural size of farm (UAA)",
#         "code": "EF_MPEQUIP",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2013"
#     },
#     {
#         "title": "Farm machinery: number of farms and machines by size of farm (UAA)",
#         "code": "EF_MPMACHINE",
#         "type": "dataset",
#         "last update of data": "2016-12-13T23:00:00+0100",
#         "last table structure change": "2024-01-03T23:00:00+0100",
#         "data start": "2013",
#         "data end": "2013"
#     },
#     {
#         "title": "Holder-manager relationship: area, livestock, labour force and standard output (SO) by agricultural size of farm (UAA)",
#         "code": "EF_MPMANAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Organic farming: number of farms, areas with different crops and heads of different types of animals by agricultural size of farm (UAA) and NUTS 2 region",
#         "code": "EF_MPORGANIC",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2003",
#         "data end": "2013"
#     },
#     {
#         "title": "Type of tenure: number of farms and areas by agricultural size of farm (UAA) and NUTS 2 region",
#         "code": "EF_MPTENURE",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Type of tenure: number of farms and areas by economic size of farm (SO in Euro) and NUTS 2 region",
#         "code": "EF_MPTENURECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Agricultural training of farm managers: number of farms, agricultural area, labour force, standard output (SO) and livestock (LSU) by economic size of farm (SO in Euro)",
#         "code": "EF_MPTRAINECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Agricultural training of farm managers: number of farms, agricultural area, labour force and standard output (SO) by age and sex of the manager",
#         "code": "EF_MPTRAINMAN",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Organic farming by age, sex and training of farm manager",
#         "code": "EF_MP_MANORG",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-03-26T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Tenure of agricultural holdings by utilised agricultural area, sex and age of farm manager",
#         "code": "EF_MP_TENURE",
#         "type": "dataset",
#         "last update of data": "2024-04-17T23:00:00+0200",
#         "last table structure change": "2024-04-25T23:00:00+0200",
#         "data start": "2005",
#         "data end": "2020"
#     },
#     {
#         "title": "Agricultural holdings and utilised agricultural area by training, age and sex of farm managers",
#         "code": "EF_MP_TRAINING",
#         "type": "dataset",
#         "last update of data": "2023-03-27T23:00:00+0200",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Share of holdings by training of farm manager and NUTS 2 region",
#         "code": "EF_MP_TRAINING_SH",
#         "type": "dataset",
#         "last update of data": "2024-05-27T23:00:00+0200",
#         "last table structure change": "2024-05-27T23:00:00+0200",
#         "data start": "2020",
#         "data end": "2020"
#     },
#     {
#         "title": "Agricultural holding and utilised agricultural area by vocational training, sex and age of farm managers",
#         "code": "EF_MP_VOCTRAINING",
#         "type": "dataset",
#         "last update of data": "2024-02-29T23:00:00+0100",
#         "last table structure change": "2024-02-29T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Share of holdings by age of farm managers and NUTS 2 region",
#         "code": "EF_M_AGE_SH",
#         "type": "dataset",
#         "last update of data": "2024-05-27T23:00:00+0200",
#         "last table structure change": "2024-05-27T23:00:00+0200",
#         "data start": "2020",
#         "data end": "2020"
#     },
#     {
#         "title": "Farm indicators by age and sex of the manager, economic size of the farm, utilised agricultural area and NUTS 2 region",
#         "code": "EF_M_FARMANG",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Farm indicators by age and sex of the manager, economic size of the farm, utilised agricultural area and NUTS 2 region",
#         "code": "EF_M_FARMANG$DV_1848",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": null,
#         "data end": null
#     },
#     {
#         "title": "Farm indicators by legal status of the holding, utilised agricultural area, type and economic size of the farm and NUTS 2 region",
#         "code": "EF_M_FARMLEG",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Main farm indicators by organic farming, utilised agricultural area, economic size, farm type of agricultural holding and NUTS 2",
#         "code": "EF_M_ORG",
#         "type": "dataset",
#         "last update of data": "2024-03-26T23:00:00+0100",
#         "last table structure change": "2024-03-26T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Land and labour productivity of agricultural holdings by sex of farm manager and type and size of the farm",
#         "code": "EF_M_PRY",
#         "type": "dataset",
#         "last update of data": "2024-09-26T11:00:00+0200",
#         "last table structure change": "2024-09-26T11:00:00+0200",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Main farm indicators by rural development support measures, utilized agricultural area, type and economic size of the farm and NUTS 2 region",
#         "code": "EF_M_RD",
#         "type": "dataset",
#         "last update of data": "2024-10-31T11:00:00+0100",
#         "last table structure change": "2024-10-31T11:00:00+0100",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Share of holdings by sex of farm managers and NUTS 2 region",
#         "code": "EF_M_SEX_SH",
#         "type": "dataset",
#         "last update of data": "2024-05-27T23:00:00+0200",
#         "last table structure change": "2024-05-27T23:00:00+0200",
#         "data start": "2020",
#         "data end": "2020"
#     },
#     {
#         "title": "Other gainful activities (OGA) of the farm of sole holder: number of farms, agricultural area, standard output (SO) and livestock (LSU) by agricultural size of farm (UAA)",
#         "code": "EF_OGAAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2017-01-16T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Other gainful activities (OGA) of the farm of sole holder: number of farms, agricultural area, standard output (SO) and livestock (LSU) by age of holder",
#         "code": "EF_OGAAGE",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2017-01-16T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Other gainful activities directly related to the holding: number of farms, agricultural area, standard output (SO) and livestock (LSU) by age and sex of holder",
#         "code": "EF_OGADSEXAGE",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Other gainful activities (OGA) of the farm of sole holder: number of farms, agricultural area, standard output (SO) and livestock (LSU) by economic size of farm (SO in Euro)",
#         "code": "EF_OGAECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2017-01-16T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Other gainful activities (OGA) of the farm of sole holder: number of farms, agricultural area, standard output (SO) and livestock (LSU) by type of farming (1-digit)",
#         "code": "EF_OGAFT",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2017-01-16T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Support for rural development: number of farms, agricultural area, standard output (SO) and livestock (LSU) by legal status of holding and agricultural size of farm (UAA)",
#         "code": "EF_OGARDAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2013"
#     },
#     {
#         "title": "Support for rural development: number of farms, agricultural area, standard output (SO) and livestock (LSU) by legal status and economic size of farm (SO in Euro)",
#         "code": "EF_OGARDLEGECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2013"
#     },
#     {
#         "title": "Support for rural development: number of farms, agricultural area, standard output (SO) and livestock (LSU) by legal status and type of farming (1-digit)",
#         "code": "EF_OGARDLEGFT",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2013"
#     },
#     {
#         "title": "Support for rural development: number of farms, agricultural area, standard output (SO) and livestock (LSU) by age and sex of holder",
#         "code": "EF_OGARDSEXAGE",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2010",
#         "data end": "2013"
#     },
#     {
#         "title": "Farm indicators by other gainful activities related to the holder, utilized agricultural area, type and economic size of the farm and NUTS 2 region",
#         "code": "EF_OGA_MAIN",
#         "type": "dataset",
#         "last update of data": "2024-04-15T23:00:00+0200",
#         "last table structure change": "2024-04-25T23:00:00+0200",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Support for rural development by legal status, size and farm typology",
#         "code": "EF_OGA_RDSIZE",
#         "type": "dataset",
#         "last update of data": "2020-07-09T23:00:00+0200",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2016",
#         "data end": "2016"
#     },
#     {
#         "title": "Type of other gainful activities directly related to the agricultural holdings by age of the manager, utilised agricultural area, farm type and economic size by NUTS 2 region",
#         "code": "EF_OGA_TYPE",
#         "type": "dataset",
#         "last update of data": "2024-08-31T11:00:00+0200",
#         "last table structure change": "2024-04-25T23:00:00+0200",
#         "data start": "2010",
#         "data end": "2020"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by agricultural size of farm (UAA)",
#         "code": "EF_OLFAA",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by type of farming (2-digit) and economic size of farm (SO in Euro)",
#         "code": "EF_OLFFTECS",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by sex of workers and NUTS 2 region",
#         "code": "EF_OLFREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Livestock: number of farms and heads of animals of different types by agricultural size of farm (UAA) and NUTS 2 region",
#         "code": "EF_OLSAAREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Livestock: number of farms and heads of animals by economic size of farm (SO in Euro) and NUTS 2 region",
#         "code": "EF_OLSECSREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Livestock: number of farms and heads of animals by type of farming (2-digit)",
#         "code": "EF_OLSLSUFT",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Livestock: number of farms and heads of animals by livestock units (LSU) of farm and NUTS 2 region",
#         "code": "EF_OLSLSUREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Land use: number of farms and areas of different crops by agricultural size of farm (UAA) and NUTS 2 region",
#         "code": "EF_OLUAAREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Land use: number of farms and areas of different crops by economic size of farm (SO in Euro) and NUTS 2 region",
#         "code": "EF_OLUECSREG",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2024-01-10T11:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Land use: number of farms and areas of different crops by type of farming (2-digit)",
#         "code": "EF_OLUFT",
#         "type": "dataset",
#         "last update of data": "2017-01-16T23:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2005",
#         "data end": "2013"
#     },
#     {
#         "title": "Key variables by legal status of holding, size of farm (UAA) and NUTS 2 region",
#         "code": "EF_OV_KVAA",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Key variables by size of farm (UAA), economic size of farm (ESU) and LFA status",
#         "code": "EF_OV_KVAAESU",
#         "type": "dataset",
#         "last update of data": "2009-07-16T23:00:00+0200",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Key variables by age of holder, size of farm (UAA) and LFA status",
#         "code": "EF_OV_KVAGE",
#         "type": "dataset",
#         "last update of data": "2009-07-16T23:00:00+0200",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Key variables by type of farming (1-digit), economic size of farm (ESU) and LFA status",
#         "code": "EF_OV_KVESUFT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2007"
#     },
#     {
#         "title": "Key variables by type of farming (2-digit) and size of farm (UAA)",
#         "code": "EF_OV_KVFTAA",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Key variables by type of farming (2-digit) and economic size of farm (ESU)",
#         "code": "EF_OV_KVFTESU",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2007"
#     },
#     {
#         "title": "Key variables by type of farming (1-digit), economic size of farm (ESU) and objective zone 2000",
#         "code": "EF_OV_KVFTOB00",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2005"
#     },
#     {
#         "title": "Key variables by type of farming (1-digit), economic size of farm (ESU) and objective zone 1999",
#         "code": "EF_OV_KVFTOB99",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2000"
#     },
#     {
#         "title": "Key variables by type of farming (2-digit) and NUTS 2 region",
#         "code": "EF_OV_KVFTREG",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2007"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by type of farming (2-digit) and economic size of farm (ESU)",
#         "code": "EF_OV_LFFT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2007"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by size of farm (UAA) and objective zone 2000",
#         "code": "EF_OV_LFOB00",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2003"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by size of farm (UAA) and objective zone 1999",
#         "code": "EF_OV_LFOB99",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2003"
#     },
#     {
#         "title": "Labour force: number of persons and farm work (AWU) by size of farm (UAA) and LFA status",
#         "code": "EF_OV_LFSUM",
#         "type": "dataset",
#         "last update of data": "2009-07-16T23:00:00+0200",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Livestock: number of farms, heads and LSU by type of farming (2-digit) and economic size of farm (ESU)",
#         "code": "EF_OV_LSFT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2007"
#     },
#     {
#         "title": "Livestock: number of farms and heads by size of farm (UAA) and objective zone 2000",
#         "code": "EF_OV_LSOB00",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2003"
#     },
#     {
#         "title": "Livestock: number of farms and heads by size of farm (UAA) and objective zone 1999",
#         "code": "EF_OV_LSOB99",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2003"
#     },
#     {
#         "title": "Livestock: number of farms and heads by size of farm (UAA) and LFA status",
#         "code": "EF_OV_LSSUM",
#         "type": "dataset",
#         "last update of data": "2009-07-16T23:00:00+0200",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "1990",
#         "data end": "2007"
#     },
#     {
#         "title": "Land use: number of farms and areas by type of farming (2-digit) and economic size of farm (ESU)",
#         "code": "EF_OV_LUFT",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2007"
#     },
#     {
#         "title": "Land use: number of farms and areas by size of farm (UAA) and objective zone 2000",
#         "code": "EF_OV_LUOB00",
#         "type": "dataset",
#         "last update of data": "2009-03-27T11:00:00+0100",
#         "last table structure change": "2023-12-21T23:00:00+0100",
#         "data start": "2000",
#         "data end": "2005"
#     }
# ]

# %% [markdown]
# # Fetch Data

# %% [markdown]
# [Euriostat rest api data](https://ec.europa.eu/eurostat/web/user-guides/data-browser/api-data-access/api-getting-started#fragment-15944082-uabj-inline-nav-3)
#
# ##  API list:
#
# *   Statistics API: Offers data in JSON-stat 2.0 format, optimized for visualization tools, supporting REST protocol and CORS; [webpage](https://ec.europa.eu/eurostat/web/user-guides/data-browser/api-data-access/api-getting-started/api?utm_source=chatgpt.com)
#   - Placeholder data: https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/DATASET_CODE?lang=EN
#
# *   SDMX 3.0 API: Enables programmatic access to metadata and data following the SDMX 3.0 specification, multlp formats , get comlete dataset;
# * SDMX 2.1 API: Provides access to metadata and data adhering to the SDMX 2.1 specification, supporting various data formats for customized queries;
# * Catalogue API: Facilitates dataset discovery through programmatic access to Eurostat's catalogue of datasets, available in XML and DCAT-AP formats (SPARQL endpoint at https://data.europa.eu/sparql)

# %%
#selected: "title": "Share of family farms by NUTS 2 region","code": "EF_LF_FAM_SH" .
# or select : EF_M_FARMANG in "title": "Farm indicators by age and sex of the manager, economic size of the farm, utilised agricultural area and NUTS 2 region",

# %%
# Define the dataset code
dataset_code = "EF_M_FARMANG" # the one in the cell of selected: ..."code"

# Construct the API URL for the dataset
url = f'https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/{dataset_code}?format=JSON&lang=EN'

# Fetch the data
response = requests.get(url)

# Check if the response is successful
if response.status_code == 200:
    data = response.json()

    # Save the JSON to a file
    with open(f'{dataset_code}_metadata.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    print(f" saved to {dataset_code}_metadata.json")
else:
    print(f"Failed to fetch data. HTTP Status Code: {response.status_code}")
# Out:
#  saved to EF_M_FARMANG_metadata.json

# %% [markdown]
# # Exploring keys used and, then, explicative docs in metadata, go to next section to get some documents to study how to use the dataset

# %%
# Load the JSON file
file_path = f'{dataset_code}_metadata.json'
with open(file_path, 'r', encoding='utf-8') as f:
    metadata = json.load(f)

# Flatten the JSON
def flatten_json(data, parent_key='', sep='.'):
    """Flatten a nested JSON object into a flat dictionary."""
    flattened = {}
    if isinstance(data, dict):
        for key, value in data.items():
            full_key = f"{parent_key}{sep}{key}" if parent_key else key
            flattened.update(flatten_json(value, full_key, sep=sep))
    elif isinstance(data, list):
        for i, item in enumerate(data):
            full_key = f"{parent_key}{sep}{i}" if parent_key else str(i)
            flattened.update(flatten_json(item, full_key, sep=sep))
    else:
        flattened[parent_key] = data
    return flattened

flattened_metadata = flatten_json(metadata)

# Convert the flattened metadata to a DataFrame
df = pd.DataFrame(flattened_metadata.items(), columns=['Key', 'Value'])

# Inspect the first few rows
print(df.tail(20))
# Out:
#                                    Key  \
# 9804700    extension.annotation.6.type
# 9804701   extension.annotation.6.title
# 9804702    extension.annotation.6.href
# 9804703    extension.annotation.7.type
# 9804704   extension.annotation.7.title
# 9804705    extension.annotation.7.href
# 9804706    extension.annotation.8.type
# 9804707   extension.annotation.8.title
# 9804708    extension.annotation.9.type
# 9804709   extension.annotation.9.title
# 9804710   extension.annotation.10.type
# 9804711  extension.annotation.10.title
# 9804712   extension.annotation.11.type
# 9804713   extension.annotation.11.text
# 9804714   extension.annotation.12.type
# 9804715   extension.annotation.12.date
# 9804716   extension.annotation.13.type
# 9804717   extension.annotation.13.date
# 9804718       extension.status.label.c
# 9804719       extension.status.label.u
#
#                                                      Value
# 9804700                                          ESMS_HTML
# 9804701                       Explanatory texts (metadata)
# 9804702  https://ec.europa.eu/eurostat/cache/metadata/e...
# 9804703                                          ESMS_SDMX
# 9804704                       Explanatory texts (metadata)
# 9804705  https://ec.europa.eu/eurostat/api/disseminatio...
# 9804706                                          OBS_COUNT
# 9804707                                            9550078
# 9804708                          OBS_PERIOD_OVERALL_LATEST
# 9804709                                               2020
# 9804710                          OBS_PERIOD_OVERALL_OLDEST
# 9804711                                               2010
# 9804712                                SOURCE_INSTITUTIONS
# 9804713                                           Eurostat
# 9804714                                        UPDATE_DATA
# 9804715                           2024-03-26T23:00:00+0100
# 9804716                                   UPDATE_STRUCTURE
# 9804717                           2024-01-10T11:00:00+0100
# 9804718                                       confidential
# 9804719                                    low reliability

# %%
df.tail(100)
# click on interactive table visualization, filter if needed
# Out:
#                                        Key  \
# 9804620  dimension.geo.category.label.UKC2
# 9804621  dimension.geo.category.label.UKD1
# 9804622  dimension.geo.category.label.UKD3
# 9804623  dimension.geo.category.label.UKD4
# 9804624  dimension.geo.category.label.UKD6
# ...                                    ...
# 9804715       extension.annotation.12.date
# 9804716       extension.annotation.13.type
# 9804717       extension.annotation.13.date
# 9804718           extension.status.label.c
# 9804719           extension.status.label.u
#
#                                                 Value
# 9804620  Northumberland and Tyne and Wear (NUTS 2021)
# 9804621                           Cumbria (NUTS 2021)
# 9804622                Greater Manchester (NUTS 2021)
# 9804623                        Lancashire (NUTS 2021)
# 9804624                          Cheshire (NUTS 2021)
# ...                                               ...
# 9804715                      2024-03-26T23:00:00+0100
# 9804716                              UPDATE_STRUCTURE
# 9804717                      2024-01-10T11:00:00+0100
# 9804718                                  confidential
# 9804719                               low reliability
#
# [100 rows x 2 columns]

# %%
# Check for 'dimension' key to explore dimensions and their categories
if 'dimension' in metadata:
    dimensions = metadata['dimension']
    print("\nDimensions available in the JSON:")
    for dim_name, dim_data in dimensions.items():
        print(f"Dimension: {dim_name}")
        if 'label' in dim_data:
            print(f"  Description: {dim_data['label']}")
        if 'category' in dim_data:
            print("  Categories:")
            categories = dim_data['category']
            # Extract category indices and labels
            index = categories.get('index', {})
            labels = categories.get('label', {})
            for code, idx in index.items():
                description = labels.get(code, 'No description available')
                print(f"    Code: {code} -> {description}")
else:
    print("\nNo 'dimension' key found in the JSON.")
# Out:
# Dimensions available in the JSON:
# Dimension: freq
#   Description: Time frequency
#   Categories:
#     Code: A -> Annual
# Dimension: sex
#   Description: Sex
#   Categories:
#     Code: T -> Total
#     Code: M -> Males
#     Code: F -> Females
# Dimension: age
#   Description: Age class
#   Categories:
#     Code: TOTAL -> Total
#     Code: Y_LT25 -> Less than 25 years
#     Code: Y25-34 -> From 25 to 34 years
#     Code: Y35-39 -> From 35 to 39 years
#     Code: Y35-44 -> From 35 to 44 years
#     Code: Y40-44 -> From 40 to 44 years
#     Code: Y45-54 -> From 45 to 54 years
#     Code: Y55-64 -> From 55 to 64 years
#     Code: Y_GE65 -> 65 years or over
# Dimension: so_eur
#   Description: Standard output in Euros
#   Categories:
#     Code: TOTAL -> Total
#     Code: KE0 -> Zero euros
#     Code: KE_GT0_LT2 -> Over zero euros to less than 2000 euros
#     Code: KE2-3 -> From 2 000 to 3 999 euros
#     Code: KE4-7 -> From 4 000 to 7 999 euros
#     Code: KE8-14 -> From 8 000 to 14 999 euros
#     Code: KE15-24 -> From 15 000 to 24 999 euros
#     Code: KE25-49 -> From 25 000 to 49 999 euros
#     Code: KE50-99 -> From 50 000 to 99 999 euros
#     Code: KE100-249 -> From 100 000 to 249 999 euros
#     Code: KE250-499 -> From 250 000 to 499 999 euros
#     Code: KE_GE500 -> 500 000 euros or over
# Dimension: uaarea
#   Description: Utilised agricultural area
#   Categories:
#     Code: TOTAL -> Total
#     Code: HA0 -> Zero ha
#     Code: HA_GT0_LT2 -> Over 0 ha to less than 2 ha
#     Code: HA2-4 -> From 2 to 4.9 ha
#     Code: HA5-9 -> From 5 to 9.9 ha
#     Code: HA10-19 -> From 10 to 19.9 ha
#     Code: HA20-29 -> From 20 to 29.9 ha
#     Code: HA30-49 -> From 30 to 49.9 ha
#     Code: HA50-99 -> From 50 to 99.9 ha
#     Code: HA_GE100 -> 100 ha or over
# Dimension: crops
#   Description: Crops
#   Categories:
#     Code: UAA -> Utilised agricultural area
# Dimension: unit
#   Description: Unit of measure
#   Categories:
#     Code: EUR -> Euro
#     Code: HA -> Hectare
#     Code: AWU -> Annual working unit (AWU)
#     Code: LSU -> Livestock unit (LSU)
#     Code: HLD -> Holding
# Dimension: geo
#   Description: Geopolitical entity (reporting)
#   Categories:
#     Code: EU -> European Union (EU6-1958, EU9-1973, EU10-1981, EU12-1986, EU15-1995, EU25-2004, EU27-2007, EU28-2013, EU27-2020)
#     Code: EU27_2020 -> European Union - 27 countries (from 2020)
#     Code: EU28 -> European Union - 28 countries (2013-2020)
#     Code: EU27_2007 -> European Union - 27 countries (2007-2013)
#     Code: BE -> Belgium
#     Code: BE10 -> Région de Bruxelles-Capitale/Brussels Hoofdstedelijk Gewest
#     Code: BE21 -> Prov. Antwerpen
#     Code: BE22 -> Prov. Limburg (BE)
#     Code: BE23 -> Prov. Oost-Vlaanderen
#     Code: BE24 -> Prov. Vlaams-Brabant
#     Code: BE25 -> Prov. West-Vlaanderen
#     Code: BE31 -> Prov. Brabant wallon
#     Code: BE32 -> Prov. Hainaut
#     Code: BE33 -> Prov. Liège
#     Code: BE34 -> Prov. Luxembourg (BE)
#     Code: BE35 -> Prov. Namur
#     Code: BG -> Bulgaria
#     Code: BG31 -> Severozapaden
#     Code: BG32 -> Severen tsentralen
#     Code: BG33 -> Severoiztochen
#     Code: BG34 -> Yugoiztochen
#     Code: BG41 -> Yugozapaden
#     Code: BG42 -> Yuzhen tsentralen
#     Code: CZ -> Czechia
#     Code: CZ01 -> Praha
#     Code: CZ02 -> Střední Čechy
#     Code: CZ03 -> Jihozápad
#     Code: CZ04 -> Severozápad
#     Code: CZ05 -> Severovýchod
#     Code: CZ06 -> Jihovýchod
#     Code: CZ07 -> Střední Morava
#     Code: CZ08 -> Moravskoslezsko
#     Code: DK -> Denmark
#     Code: DK01 -> Hovedstaden
#     Code: DK02 -> Sjælland
#     Code: DK03 -> Syddanmark
#     Code: DK04 -> Midtjylland
#     Code: DK05 -> Nordjylland
#     Code: DE -> Germany
#     Code: DE11 -> Stuttgart
#     Code: DE12 -> Karlsruhe
#     Code: DE13 -> Freiburg
#     Code: DE14 -> Tübingen
#     Code: DE21 -> Oberbayern
#     Code: DE22 -> Niederbayern
#     Code: DE23 -> Oberpfalz
#     Code: DE24 -> Oberfranken
#     Code: DE25 -> Mittelfranken
#     Code: DE26 -> Unterfranken
#     Code: DE27 -> Schwaben
#     Code: DE30 -> Berlin
#     Code: DE40 -> Brandenburg
#     Code: DE50 -> Bremen
#     Code: DE60 -> Hamburg
#     Code: DE71 -> Darmstadt
#     Code: DE72 -> Gießen
#     Code: DE73 -> Kassel
#     Code: DE80 -> Mecklenburg-Vorpommern
#     Code: DE91 -> Braunschweig
#     Code: DE92 -> Hannover
#     Code: DE93 -> Lüneburg
#     Code: DE94 -> Weser-Ems
#     Code: DEA1 -> Düsseldorf
#     Code: DEA2 -> Köln
#     Code: DEA3 -> Münster
#     Code: DEA4 -> Detmold
#     Code: DEA5 -> Arnsberg
#     Code: DEB1 -> Koblenz
#     Code: DEB2 -> Trier
#     Code: DEB3 -> Rheinhessen-Pfalz
#     Code: DEC0 -> Saarland
#     Code: DED2 -> Dresden
#     Code: DED4 -> Chemnitz
#     Code: DED5 -> Leipzig
#     Code: DEE0 -> Sachsen-Anhalt
#     Code: DEF0 -> Schleswig-Holstein
#     Code: DEG0 -> Thüringen
#     Code: EE -> Estonia
#     Code: EE00 -> Eesti
#     Code: IE -> Ireland
#     Code: IE04 -> Northern and Western
#     Code: IE05 -> Southern
#     Code: IE06 -> Eastern and Midland
#     Code: IE01 -> Border, Midland and Western (NUTS 2013)
#     Code: IE02 -> Southern and Eastern (NUTS 2013)
#     Code: EL -> Greece
#     Code: EL11 -> Anatoliki Makedonia, Thraki (NUTS 2010)
#     Code: EL12 -> Kentriki Makedonia (NUTS 2010)
#     Code: EL13 -> Dytiki Makedonia (NUTS 2010)
#     Code: EL14 -> Thessalia (NUTS 2010)
#     Code: EL21 -> Ipeiros (NUTS 2010)
#     Code: EL22 -> Ionia Nisia (NUTS 2010)
#     Code: EL23 -> Dytiki Ellada (NUTS 2010)
#     Code: EL24 -> Sterea Ellada (NUTS 2010)
#     Code: EL25 -> Peloponnisos (NUTS 2010)
#     Code: EL30 -> Attiki
#     Code: EL41 -> Voreio Aigaio
#     Code: EL42 -> Notio Aigaio
#     Code: EL43 -> Kriti
#     Code: EL51 -> Anatoliki Makedonia, Thraki
#     Code: EL52 -> Kentriki Makedonia
#     Code: EL53 -> Dytiki Makedonia
#     Code: EL54 -> Ipeiros
#     Code: EL61 -> Thessalia
#     Code: EL62 -> Ionia Nisia
#     Code: EL63 -> Dytiki Elláda
#     Code: EL64 -> Sterea Elláda
#     Code: EL65 -> Peloponnisos
#     Code: ELZZ -> Extra-Regio NUTS 2
#     Code: ES -> Spain
#     Code: ES11 -> Galicia
#     Code: ES12 -> Principado de Asturias
#     Code: ES13 -> Cantabria
#     Code: ES21 -> País Vasco
#     Code: ES22 -> Comunidad Foral de Navarra
#     Code: ES23 -> La Rioja
#     Code: ES24 -> Aragón
#     Code: ES30 -> Comunidad de Madrid
#     Code: ES41 -> Castilla y León
#     Code: ES42 -> Castilla-La Mancha
#     Code: ES43 -> Extremadura
#     Code: ES51 -> Cataluña
#     Code: ES52 -> Comunitat Valenciana
#     Code: ES53 -> Illes Balears
#     Code: ES61 -> Andalucía
#     Code: ES62 -> Región de Murcia
#     Code: ES63 -> Ciudad de Ceuta
#     Code: ES64 -> Ciudad de Melilla
#     Code: ES70 -> Canarias
#     Code: FR -> France
#     Code: FR10 -> Ile de France
#     Code: FRB0 -> Centre — Val de Loire
#     Code: FRC1 -> Bourgogne
#     Code: FRC2 -> Franche-Comté
#     Code: FRD1 -> Basse-Normandie
#     Code: FRD2 -> Haute-Normandie
#     Code: FRE1 -> Nord-Pas de Calais
#     Code: FRE2 -> Picardie
#     Code: FRF1 -> Alsace
#     Code: FRF2 -> Champagne-Ardenne
#     Code: FRF3 -> Lorraine
#     Code: FRG0 -> Pays de la Loire
#     Code: FRH0 -> Bretagne
#     Code: FRI1 -> Aquitaine
#     Code: FRI2 -> Limousin
#     Code: FRI3 -> Poitou-Charentes
#     Code: FRJ1 -> Languedoc-Roussillon
#     Code: FRJ2 -> Midi-Pyrénées
#     Code: FRK1 -> Auvergne
#     Code: FRK2 -> Rhône-Alpes
#     Code: FRL0 -> Provence-Alpes-Côte d’Azur
#     Code: FRM0 -> Corse
#     Code: FRY1 -> Guadeloupe
#     Code: FRY2 -> Martinique
#     Code: FRY3 -> Guyane
#     Code: FRY4 -> La Réunion
#     Code: FRY5 -> Mayotte
#     Code: FR21 -> Champagne-Ardenne (NUTS 2013)
#     Code: FR22 -> Picardie (NUTS 2013)
#     Code: FR23 -> Haute-Normandie (NUTS 2013)
#     Code: FR24 -> Centre (FR) (NUTS 2013)
#     Code: FR25 -> Basse-Normandie (NUTS 2013)
#     Code: FR26 -> Bourgogne (NUTS 2013)
#     Code: FR30 -> Nord-Pas-de-Calais (NUTS 2013)
#     Code: FR41 -> Lorraine (NUTS 2013)
#     Code: FR42 -> Alsace (NUTS 2013)
#     Code: FR43 -> Franche-Comté (NUTS 2013)
#     Code: FR51 -> Pays de la Loire (NUTS 2013)
#     Code: FR52 -> Bretagne (NUTS 2013)
#     Code: FR53 -> Poitou-Charentes (NUTS 2013)
#     Code: FR61 -> Aquitaine (NUTS 2013)
#     Code: FR62 -> Midi-Pyrénées (NUTS 2013)
#     Code: FR63 -> Limousin (NUTS 2013)
#     Code: FR71 -> Rhône-Alpes (NUTS 2013)
#     Code: FR72 -> Auvergne (NUTS 2013)
#     Code: FR81 -> Languedoc-Roussillon (NUTS 2013)
#     Code: FR82 -> Provence-Alpes-Côte d'Azur (NUTS 2013)
#     Code: FR83 -> Corse (NUTS 2013)
#     Code: FRA1 -> Guadeloupe (NUTS 2013)
#     Code: FRA2 -> Martinique (NUTS 2013)
#     Code: FRA3 -> Guyane (NUTS 2013)
#     Code: FRA4 -> La Réunion (NUTS 2013)
#     Code: FR91 -> Guadeloupe (NUTS 2010)
#     Code: FR92 -> Martinique (NUTS 2010)
#     Code: FR93 -> Guyane (NUTS 2010)
#     Code: FR94 -> Réunion (NUTS 2010)
#     Code: HR -> Croatia
#     Code: HR02 -> Panonska Hrvatska
#     Code: HR03 -> Jadranska Hrvatska
#     Code: HR04 -> Kontinentalna Hrvatska (NUTS 2016)
#     Code: HR05 -> Grad Zagreb
#     Code: HR06 -> Sjeverna Hrvatska
#     Code: IT -> Italy
#     Code: ITC1 -> Piemonte
#     Code: ITC2 -> Valle d’Aosta/Vallée d’Aoste
#     Code: ITC3 -> Liguria
#     Code: ITC4 -> Lombardia
#     Code: ITF1 -> Abruzzo
#     Code: ITF2 -> Molise
#     Code: ITF3 -> Campania
#     Code: ITF4 -> Puglia
#     Code: ITF5 -> Basilicata
#     Code: ITF6 -> Calabria
#     Code: ITG1 -> Sicilia
#     Code: ITG2 -> Sardegna
#     Code: ITH1 -> Provincia Autonoma di Bolzano/Bozen
#     Code: ITH2 -> Provincia Autonoma di Trento
#     Code: ITH3 -> Veneto
#     Code: ITH4 -> Friuli-Venezia Giulia
#     Code: ITH5 -> Emilia-Romagna
#     Code: ITI1 -> Toscana
#     Code: ITI2 -> Umbria
#     Code: ITI3 -> Marche
#     Code: ITI4 -> Lazio
#     Code: CY -> Cyprus
#     Code: CY00 -> Kýpros
#     Code: LV -> Latvia
#     Code: LV00 -> Latvija
#     Code: LT -> Lithuania
#     Code: LT01 -> Sostinės regionas
#     Code: LT02 -> Vidurio ir vakarų Lietuvos regionas
#     Code: LT00 -> Lietuva (NUTS 2013)
#     Code: LU -> Luxembourg
#     Code: LU00 -> Luxembourg
#     Code: HU -> Hungary
#     Code: HU11 -> Budapest
#     Code: HU12 -> Pest
#     Code: HU10 -> Közép-Magyarország (NUTS 2013)
#     Code: HU21 -> Közép-Dunántúl
#     Code: HU22 -> Nyugat-Dunántúl
#     Code: HU23 -> Dél-Dunántúl
#     Code: HU31 -> Észak-Magyarország
#     Code: HU32 -> Észak-Alföld
#     Code: HU33 -> Dél-Alföld
#     Code: MT -> Malta
#     Code: MT00 -> Malta
#     Code: NL -> Netherlands
#     Code: NL11 -> Groningen
#     Code: NL12 -> Friesland (NL)
#     Code: NL13 -> Drenthe
#     Code: NL21 -> Overijssel
#     Code: NL22 -> Gelderland
#     Code: NL23 -> Flevoland
#     Code: NL31 -> Utrecht (NUTS 2021)
#     Code: NL32 -> Noord-Holland
#     Code: NL33 -> Zuid-Holland (NUTS 2021)
#     Code: NL34 -> Zeeland
#     Code: NL41 -> Noord-Brabant
#     Code: NL42 -> Limburg (NL)
#     Code: AT -> Austria
#     Code: AT11 -> Burgenland
#     Code: AT12 -> Niederösterreich
#     Code: AT13 -> Wien
#     Code: AT21 -> Kärnten
#     Code: AT22 -> Steiermark
#     Code: AT31 -> Oberösterreich
#     Code: AT32 -> Salzburg
#     Code: AT33 -> Tirol
#     Code: AT34 -> Vorarlberg
#     Code: PL -> Poland
#     Code: PL11 -> Lódzkie (NUTS 2013)
#     Code: PL12 -> Mazowieckie (NUTS 2013)
#     Code: PL21 -> Małopolskie
#     Code: PL22 -> Śląskie
#     Code: PL31 -> Lubelskie (NUTS 2013)
#     Code: PL32 -> Podkarpackie (NUTS 2013)
#     Code: PL33 -> Swietokrzyskie (NUTS 2013)
#     Code: PL34 -> Podlaskie (NUTS 2013)
#     Code: PL41 -> Wielkopolskie
#     Code: PL42 -> Zachodniopomorskie
#     Code: PL43 -> Lubuskie
#     Code: PL51 -> Dolnośląskie
#     Code: PL52 -> Opolskie
#     Code: PL61 -> Kujawsko-pomorskie
#     Code: PL62 -> Warmińsko-mazurskie
#     Code: PL63 -> Pomorskie
#     Code: PL71 -> Łódzkie
#     Code: PL72 -> Świętokrzyskie
#     Code: PL81 -> Lubelskie
#     Code: PL82 -> Podkarpackie
#     Code: PL84 -> Podlaskie
#     Code: PL91 -> Warszawski stołeczny
#     Code: PL92 -> Mazowiecki regionalny
#     Code: PT -> Portugal
#     Code: PT11 -> Norte
#     Code: PT15 -> Algarve
#     Code: PT16 -> Centro (PT) (NUTS 2021)
#     Code: PT17 -> Área Metropolitana de Lisboa (NUTS 2021)
#     Code: PT18 -> Alentejo (NUTS 2021)
#     Code: PT20 -> Região Autónoma dos Açores
#     Code: PT30 -> Região Autónoma da Madeira
#     Code: RO -> Romania
#     Code: RO11 -> Nord-Vest
#     Code: RO12 -> Centru
#     Code: RO21 -> Nord-Est
#     Code: RO22 -> Sud-Est
#     Code: RO31 -> Sud-Muntenia
#     Code: RO32 -> Bucureşti-Ilfov
#     Code: RO41 -> Sud-Vest Oltenia
#     Code: RO42 -> Vest
#     Code: SI -> Slovenia
#     Code: SI03 -> Vzhodna Slovenija
#     Code: SI01 -> Vzhodna Slovenija (NUTS 2010)
#     Code: SI04 -> Zahodna Slovenija
#     Code: SI02 -> Zahodna Slovenija (NUTS 2010)
#     Code: SK -> Slovakia
#     Code: SK01 -> Bratislavský kraj
#     Code: SK02 -> Západné Slovensko
#     Code: SK03 -> Stredné Slovensko
#     Code: SK04 -> Východné Slovensko
#     Code: FI -> Finland
#     Code: FI19 -> Länsi-Suomi
#     Code: FI1B -> Helsinki-Uusimaa
#     Code: FI1C -> Etelä-Suomi
#     Code: FI1D -> Pohjois- ja Itä-Suomi
#     Code: FI20 -> Åland
#     Code: SE -> Sweden
#     Code: SE11 -> Stockholm
#     Code: SE12 -> Östra Mellansverige
#     Code: SE21 -> Småland med öarna
#     Code: SE22 -> Sydsverige
#     Code: SE23 -> Västsverige
#     Code: SE31 -> Norra Mellansverige
#     Code: SE32 -> Mellersta Norrland
#     Code: SE33 -> Övre Norrland
#     Code: IS -> Iceland
#     Code: IS00 -> Ísland
#     Code: NO -> Norway
#     Code: NO01 -> Oslo og Akershus (statistical region 2016)
#     Code: NO02 -> Innlandet
#     Code: NO03 -> Sør-Østlandet (statistical region 2016)
#     Code: NO04 -> Agder og Rogaland (statistical region 2016)
#     Code: NO05 -> Vestlandet (statistical region 2016)
#     Code: NO06 -> Trøndelag
#     Code: NO07 -> Nord-Norge
#     Code: NO08 -> Oslo og Viken
#     Code: NO09 -> Agder og Sør-Østlandet
#     Code: NO0A -> Vestlandet
#     Code: CH -> Switzerland
#     Code: CH01 -> Région lémanique
#     Code: CH02 -> Espace Mittelland
#     Code: CH03 -> Nordwestschweiz
#     Code: CH04 -> Zürich
#     Code: CH05 -> Ostschweiz
#     Code: CH06 -> Zentralschweiz
#     Code: CH07 -> Ticino
#     Code: UK -> United Kingdom
#     Code: UKC1 -> Tees Valley and Durham (NUTS 2021)
#     Code: UKC2 -> Northumberland and Tyne and Wear (NUTS 2021)
#     Code: UKD1 -> Cumbria (NUTS 2021)
#     Code: UKD3 -> Greater Manchester (NUTS 2021)
#     Code: UKD4 -> Lancashire (NUTS 2021)
#     Code: UKD6 -> Cheshire (NUTS 2021)
#     Code: UKD7 -> Merseyside (NUTS 2021)
#     Code: UKE1 -> East Yorkshire and Northern Lincolnshire (NUTS 2021)
#     Code: UKE2 -> North Yorkshire (NUTS 2021)
#     Code: UKE3 -> South Yorkshire (NUTS 2021)
#     Code: UKE4 -> West Yorkshire (NUTS 2021)
#     Code: UKF1 -> Derbyshire and Nottinghamshire (NUTS 2021)
#     Code: UKF2 -> Leicestershire, Rutland and Northamptonshire (NUTS 2021)
#     Code: UKF3 -> Lincolnshire (NUTS 2021)
#     Code: UKG1 -> Herefordshire, Worcestershire and Warwickshire (NUTS 2021)
#     Code: UKG2 -> Shropshire and Staffordshire (NUTS 2021)
#     Code: UKG3 -> West Midlands (NUTS 2021)
#     Code: UKH1 -> East Anglia (NUTS 2021)
#     Code: UKH2 -> Bedfordshire and Hertfordshire (NUTS 2021)
#     Code: UKH3 -> Essex (NUTS 2021)
#     Code: UKI1 -> Inner London (NUTS 2010)
#     Code: UKI2 -> Outer London (NUTS 2010)
#     Code: UKI5 -> Outer London - East and North East (NUTS 2021)
#     Code: UKI6 -> Outer London - South (NUTS 2021)
#     Code: UKI7 -> Outer London - West and North West (NUTS 2021)
#     Code: UKJ1 -> Berkshire, Buckinghamshire and Oxfordshire (NUTS 2021)
#     Code: UKJ2 -> Surrey, East and West Sussex (NUTS 2021)
#     Code: UKJ3 -> Hampshire and Isle of Wight (NUTS 2021)
#     Code: UKJ4 -> Kent (NUTS 2021)
#     Code: UKK1 -> Gloucestershire, Wiltshire and Bristol/Bath area (NUTS 2021)
#     Code: UKK2 -> Dorset and Somerset (NUTS 2021)
#     Code: UKK3 -> Cornwall and Isles of Scilly (NUTS 2021)
#     Code: UKK4 -> Devon (NUTS 2021)
#     Code: UKL1 -> West Wales and The Valleys (NUTS 2021)
#     Code: UKL2 -> East Wales (NUTS 2021)
#     Code: UKM2 -> Eastern Scotland (NUTS 2013)
#     Code: UKM3 -> South Western Scotland (NUTS 2013)
#     Code: UKM5 -> North Eastern Scotland (NUTS 2021)
#     Code: UKM6 -> Highlands and Islands (NUTS 2021)
#     Code: UKN0 -> Northern Ireland (UK) (NUTS 2021)
#     Code: ME -> Montenegro
#     Code: ME00 -> Crna Gora
#     Code: MK -> North Macedonia
#     Code: MK00 -> Severna Makedonija
#     Code: RS -> Serbia
#     Code: RS11 -> Beogradski region
#     Code: RS12 -> Region Vojvodine
#     Code: RS21 -> Region Sumadije i Zapadne Srbije
#     Code: RS22 -> Region Juzne i Istocne Srbije
# Dimension: time
#   Description: Time
#   Categories:
#     Code: 2010 -> 2010
#     Code: 2013 -> 2013
#     Code: 2016 -> 2016
#     Code: 2020 -> 2020

# %%
# Filter rows where the Key contains "href" (URLs)
urls = df[df['Key'].str.contains('href')]

# Extract relevant columns: Key (description) and Value (URL)
urls_filtered = urls[['Key', 'Value']]

# Convert to dictionary for JSON export
urls_dict = urls_filtered.set_index('Key')['Value'].to_dict()

# Save to a JSON file
output_file = 'extracted_urls.json'
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(urls_dict, f, ensure_ascii=False, indent=4)

print(f"URLs saved to {output_file}")
#From the last output above : extracted_url.json
print(json.dumps(urls_dict, indent=1, ensure_ascii=False))
# Out:
# URLs saved to extracted_urls.json
# {
#  "extension.annotation.2.href": "https://ec.europa.eu/eurostat/databrowser-backend/api/public/explanatory-notes/get/Info_note_EF_M_FARMANG_20230427.pdf",
#  "extension.annotation.3.href": "https://ec.europa.eu/eurostat/databrowser-backend/api/public/explanatory-notes/get/Info_note_EF_M_FARMANG_20230427.pdf",
#  "extension.annotation.4.href": "https://ec.europa.eu/eurostat/databrowser-backend/api/public/explanatory-notes/get/Info_note_EF_M_FARMANG_20230427.pdf",
#  "extension.annotation.6.href": "https://ec.europa.eu/eurostat/cache/metadata/en/ef_sims.htm",
#  "extension.annotation.7.href": "https://ec.europa.eu/eurostat/api/dissemination/files?file=metadata/ef_sims.sdmx.zip"
# }

# %%
# open the htm link

# %% [markdown]
# # Exploration of dataset var part II

# %%
data['dimension']['age']['category']['index']
# Out:
# {'TOTAL': 0,
#  'Y_LT25': 1,
#  'Y25-34': 2,
#  'Y35-39': 3,
#  'Y35-44': 4,
#  'Y40-44': 5,
#  'Y45-54': 6,
#  'Y55-64': 7,
#  'Y_GE65': 8}

# %%
print(data.keys())
# Out:
# dict_keys(['version', 'class', 'label', 'source', 'updated', 'value', 'status', 'id', 'size', 'dimension', 'extension'])

# %%
print(data['dimension'].keys())
# Out:
# dict_keys(['freq', 'sex', 'age', 'so_eur', 'uaarea', 'crops', 'unit', 'geo', 'time'])

# %%
print(data['dimension']['age']['category'])
print(data['dimension']['sex']['category'])
# Out:
# {'index': {'TOTAL': 0, 'Y_LT25': 1, 'Y25-34': 2, 'Y35-39': 3, 'Y35-44': 4, 'Y40-44': 5, 'Y45-54': 6, 'Y55-64': 7, 'Y_GE65': 8}, 'label': {'TOTAL': 'Total', 'Y_LT25': 'Less than 25 years', 'Y25-34': 'From 25 to 34 years', 'Y35-39': 'From 35 to 39 years', 'Y35-44': 'From 35 to 44 years', 'Y40-44': 'From 40 to 44 years', 'Y45-54': 'From 45 to 54 years', 'Y55-64': 'From 55 to 64 years', 'Y_GE65': '65 years or over'}}
# {'index': {'T': 0, 'M': 1, 'F': 2}, 'label': {'T': 'Total', 'M': 'Males', 'F': 'Females'}}

# %%
print(data['dimension']['geo']['category'])
# Out:
# {'index': {'EU': 0, 'EU27_2020': 1, 'EU28': 2, 'EU27_2007': 3, 'BE': 4, 'BE10': 5, 'BE21': 6, 'BE22': 7, 'BE23': 8, 'BE24': 9, 'BE25': 10, 'BE31': 11, 'BE32': 12, 'BE33': 13, 'BE34': 14, 'BE35': 15, 'BG': 16, 'BG31': 17, 'BG32': 18, 'BG33': 19, 'BG34': 20, 'BG41': 21, 'BG42': 22, 'CZ': 23, 'CZ01': 24, 'CZ02': 25, 'CZ03': 26, 'CZ04': 27, 'CZ05': 28, 'CZ06': 29, 'CZ07': 30, 'CZ08': 31, 'DK': 32, 'DK01': 33, 'DK02': 34, 'DK03': 35, 'DK04': 36, 'DK05': 37, 'DE': 38, 'DE11': 39, 'DE12': 40, 'DE13': 41, 'DE14': 42, 'DE21': 43, 'DE22': 44, 'DE23': 45, 'DE24': 46, 'DE25': 47, 'DE26': 48, 'DE27': 49, 'DE30': 50, 'DE40': 51, 'DE50': 52, 'DE60': 53, 'DE71': 54, 'DE72': 55, 'DE73': 56, 'DE80': 57, 'DE91': 58, 'DE92': 59, 'DE93': 60, 'DE94': 61, 'DEA1': 62, 'DEA2': 63, 'DEA3': 64, 'DEA4': 65, 'DEA5': 66, 'DEB1': 67, 'DEB2': 68, 'DEB3': 69, 'DEC0': 70, 'DED2': 71, 'DED4': 72, 'DED5': 73, 'DEE0': 74, 'DEF0': 75, 'DEG0': 76, 'EE': 77, 'EE00': 78, 'IE': 79, 'IE04': 80, 'IE05': 81, 'IE06': 82, 'IE01': 83, 'IE02': 84, 'EL': 85, 'EL11': 86, 'EL12': 87, 'EL13': 88, 'EL14': 89, 'EL21': 90, 'EL22': 91, 'EL23': 92, 'EL24': 93, 'EL25': 94, 'EL30': 95, 'EL41': 96, 'EL42': 97, 'EL43': 98, 'EL51': 99, 'EL52': 100, 'EL53': 101, 'EL54': 102, 'EL61': 103, 'EL62': 104, 'EL63': 105, 'EL64': 106, 'EL65': 107, 'ELZZ': 108, 'ES': 109, 'ES11': 110, 'ES12': 111, 'ES13': 112, 'ES21': 113, 'ES22': 114, 'ES23': 115, 'ES24': 116, 'ES30': 117, 'ES41': 118, 'ES42': 119, 'ES43': 120, 'ES51': 121, 'ES52': 122, 'ES53': 123, 'ES61': 124, 'ES62': 125, 'ES63': 126, 'ES64': 127, 'ES70': 128, 'FR': 129, 'FR10': 130, 'FRB0': 131, 'FRC1': 132, 'FRC2': 133, 'FRD1': 134, 'FRD2': 135, 'FRE1': 136, 'FRE2': 137, 'FRF1': 138, 'FRF2': 139, 'FRF3': 140, 'FRG0': 141, 'FRH0': 142, 'FRI1': 143, 'FRI2': 144, 'FRI3': 145, 'FRJ1': 146, 'FRJ2': 147, 'FRK1': 148, 'FRK2': 149, 'FRL0': 150, 'FRM0': 151, 'FRY1': 152, 'FRY2': 153, 'FRY3': 154, 'FRY4': 155, 'FRY5': 156, 'FR21': 157, 'FR22': 158, 'FR23': 159, 'FR24': 160, 'FR25': 161, 'FR26': 162, 'FR30': 163, 'FR41': 164, 'FR42': 165, 'FR43': 166, 'FR51': 167, 'FR52': 168, 'FR53': 169, 'FR61': 170, 'FR62': 171, 'FR63': 172, 'FR71': 173, 'FR72': 174, 'FR81': 175, 'FR82': 176, 'FR83': 177, 'FRA1': 178, 'FRA2': 179, 'FRA3': 180, 'FRA4': 181, 'FR91': 182, 'FR92': 183, 'FR93': 184, 'FR94': 185, 'HR': 186, 'HR02': 187, 'HR03': 188, 'HR04': 189, 'HR05': 190, 'HR06': 191, 'IT': 192, 'ITC1': 193, 'ITC2': 194, 'ITC3': 195, 'ITC4': 196, 'ITF1': 197, 'ITF2': 198, 'ITF3': 199, 'ITF4': 200, 'ITF5': 201, 'ITF6': 202, 'ITG1': 203, 'ITG2': 204, 'ITH1': 205, 'ITH2': 206, 'ITH3': 207, 'ITH4': 208, 'ITH5': 209, 'ITI1': 210, 'ITI2': 211, 'ITI3': 212, 'ITI4': 213, 'CY': 214, 'CY00': 215, 'LV': 216, 'LV00': 217, 'LT': 218, 'LT01': 219, 'LT02': 220, 'LT00': 221, 'LU': 222, 'LU00': 223, 'HU': 224, 'HU11': 225, 'HU12': 226, 'HU10': 227, 'HU21': 228, 'HU22': 229, 'HU23': 230, 'HU31': 231, 'HU32': 232, 'HU33': 233, 'MT': 234, 'MT00': 235, 'NL': 236, 'NL11': 237, 'NL12': 238, 'NL13': 239, 'NL21': 240, 'NL22': 241, 'NL23': 242, 'NL31': 243, 'NL32': 244, 'NL33': 245, 'NL34': 246, 'NL41': 247, 'NL42': 248, 'AT': 249, 'AT11': 250, 'AT12': 251, 'AT13': 252, 'AT21': 253, 'AT22': 254, 'AT31': 255, 'AT32': 256, 'AT33': 257, 'AT34': 258, 'PL': 259, 'PL11': 260, 'PL12': 261, 'PL21': 262, 'PL22': 263, 'PL31': 264, 'PL32': 265, 'PL33': 266, 'PL34': 267, 'PL41': 268, 'PL42': 269, 'PL43': 270, 'PL51': 271, 'PL52': 272, 'PL61': 273, 'PL62': 274, 'PL63': 275, 'PL71': 276, 'PL72': 277, 'PL81': 278, 'PL82': 279, 'PL84': 280, 'PL91': 281, 'PL92': 282, 'PT': 283, 'PT11': 284, 'PT15': 285, 'PT16': 286, 'PT17': 287, 'PT18': 288, 'PT20': 289, 'PT30': 290, 'RO': 291, 'RO11': 292, 'RO12': 293, 'RO21': 294, 'RO22': 295, 'RO31': 296, 'RO32': 297, 'RO41': 298, 'RO42': 299, 'SI': 300, 'SI03': 301, 'SI01': 302, 'SI04': 303, 'SI02': 304, 'SK': 305, 'SK01': 306, 'SK02': 307, 'SK03': 308, 'SK04': 309, 'FI': 310, 'FI19': 311, 'FI1B': 312, 'FI1C': 313, 'FI1D': 314, 'FI20': 315, 'SE': 316, 'SE11': 317, 'SE12': 318 ...

# %%
print(data['id'])
# Out:
# ['freq', 'sex', 'age', 'so_eur', 'uaarea', 'crops', 'unit', 'geo', 'time']

# %%
print(data['size'])
# Out:
# [1, 3, 9, 12, 10, 1, 5, 396, 4]

# %%
dim_sizes = data['size']
freq_size, sex_size, age_size, so_eur_size, uaarea_size, crops_size, unit_size, geo_size, time_size = dim_sizes
